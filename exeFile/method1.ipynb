# %%
from pandas import *
import numpy as np
import os
import function
import DataHandling
import DataPreprocess

# %%
collectedDate_list = ['0314-0316', '0317-0319', '0320-0327', '0328-0407', '0408-0423', '0424-0514', '0515-0605', '0606-062702', '062714-0717', '0718-0807', '0808-082602', '082614-0918', '0919-1013']
fractionlist = ['_alliance', '_horde']
qualitylist = ['Poor', 'Common', 'Uncommon', 'Rare', 'Epic', 'Legendary', 'Heirloom']
qualityIDlist = [0, 1, 2, 3, 4, 5, 7]
classlist = ['Consumable', 'Container', 'Weapon', 'Gem', 'Armor', 'Projectile', 'Trade Goods', 'Book', 'Money', 'Quest', 'Key', 'Junk', 'Glyph', 'Caged Pet']
classIDlist = [0, 1, 2, 3, 4, 6, 7, 9, 10, 12, 13, 15, 16, 17]
fractionlist = ['_alliance', '_horde']

fields_name = 'Realm Name,Export Time,PMktPrice Date,Reserved,Item ID,Item Name,AH MarketPrice Coppers,AH Quantity,AH MarketPrice,AH MinimumPrice,14-day Median Market Price,Median Market Price StdDev,14-day Todays PMktPrice,PMktPrice StdDev,Daily Price Change,Avg Daily Posted,Avg Estimated Daily Sold,Estimated Demand\n' 
fields_name = fields_name.replace(' ', '_')

source_dir = '../sourceFile/'
working_dir = '../workingFile/'
# comment three lines below if the data are in local computer
usb_mode = '/Volumes/TOSHIBA/'
source_dir = usb_mode + source_dir[3:]
working_dir = usb_mode + working_dir[3:] + '0313-1012/'

pop_dir = source_dir + 'population/'
auction_dir = source_dir + 'auctionData/'
csv_dir = source_dir + 'csvFile/'
itemlist = read_csv(source_dir+'itemlist.csv')

# %%
#pve_top_low_5 = read_csv(working_dir + 'pve_top_low_5')
#pvp_top_low_5 = read_csv(working_dir + 'pvp_top_low_5')
reading_dir = 'pve_top_low_5/'
for auction_name in os.listdir(working_dir + reading_dir):
    auction = read_csv(working_dir + reading_dir + auction_name)

    auction = DataHandling.getTimeRangeData(auction)
    auction['Week Num'] = auction['PMktPrice Date'].apply(DataHandling.toWeekNumber)
    temp_auction = DataHandling.removeUselessColumns(auction, remain_columns=['Item ID','Week Num','AH MarketPrice'])
    auction = DataHandling.removeUselessColumns(auction, remain_columns=['Item ID','Week Num','Avg Daily Posted'])
    
    temp_auction = DataHandling.removeOutlierOfDailyPrice(temp_auction)
    auction = auction.merge(temp_auction, on=['Item ID','Week Num'],right_index=True,left_index=True)
    auction = DataHandling.calItemsProfit(auction)
    auction.drop_duplicates(inplace=True)
    
    auction = auction.ix[:, ['Week Num','Item ID','Avg Daily Posted','Profit']]
    grouped_auction = auction.groupby(['Week Num','Item ID'], as_index=False)

    # get "item weekly quantity"
    item_q_weekly_mean = grouped_auction['Avg Daily Posted'].mean()

    # get "totoal profit of a week"
    item_profit_weekly_mean = grouped_auction['Profit'].mean()
    realm_weekly_profit = item_profit_weekly_mean.groupby(['Week Num'])['Profit'].sum()
    item_weekly_profit = DataFrame(realm_weekly_profit, columns=['Profit']).reset_index()
    auction = item_q_weekly_mean.merge(item_weekly_profit)
    
    temp_id_list = auction['Item ID']
    temp_id_list = temp_id_list.drop_duplicates()
    id_list = temp_id_list.tolist()
    
    item_corr_df = DataFrame(columns=['Item ID','Corr'])
    for item in id_list:
        temp_item = auction[auction['Item ID']==item]
        corr = np.corrcoef(x=temp_item['Avg Daily Posted'], y=temp_item['Profit'])
        new_corr = DataFrame([{'Item ID':item, 'Corr':corr[0][1]}])
        item_corr_df = item_corr_df.append(new_corr, ignore_index=True)
    item_corr_df.to_csv('../data/'+auction_name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c97f30c1d55e> in <module>()
#       6
#       7     auction = DataHandling.getTimeRangeData(auction)
# ----> 8     auction['Week Num'] = auction['PMktPrice Date'].apply(DataHandling.toWeekNumber)
#       9     temp_auction = DataHandling.removeUselessColumns(auction, remain_columns=['Item ID','Week Num','AH MarketPrice'])
#      10     auction = DataHandling.removeUselessColumns(auction, remain_columns=['Item ID','Week Num','Avg Daily Posted'])
#
# /usr/local/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2021             values = lib.map_infer(values, lib.Timestamp)
#    2022
# -> 2023         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2024         if len(mapped) and isinstance(mapped[0], Series):
#    2025             from pandas.core.frame import DataFrame
#
# /usr/local/lib/python2.7/site-packages/pandas/lib.so in pandas.lib.map_infer (pandas/lib.c:43334)()
#
# /Users/jlin/Documents/Project/WoW-Auction-Analyser/exeFile/DataHandling.pyc in toWeekNumber(val)
#      34 #########################################################################################################
#      35 def toWeekNumber(val):
# ---> 36   return Timestamp(val).week
#      37
#      38 #########################################################################################################
#
# KeyboardInterrupt:

# %% [markdown]
# 1. Read data
# 2. get only the time range needed
# 3. Add 'Week Num' column
# 4. Remove useless columns (in order to calcaulate daily price outliers)

# %%
auction = read_csv(working_dir + 'pve_top_low_5/area-52_alliance.csv')
auction = DataHandling.getTimeRangeData(auction)
auction['Week Num'] = auction['PMktPrice Date'].apply(DataHandling.toWeekNumber)
temp_auction = DataHandling.removeUselessColumns(auction, remain_columns=['Item ID','Week Num','AH MarketPrice'])
auction = DataHandling.removeUselessColumns(auction, remain_columns=['Item ID','Week Num','Avg Daily Posted'])

# %% [markdown]
# 1. Remove outliers of daily price
# 2. Add item profit column (which is the profit of that item in that day)
# 3. Drop the duplicate rows

# %%
temp_auction = DataHandling.removeOutlierOfDailyPrice(temp_auction)
auction = auction.merge(temp_auction, on=['Item ID','Week Num'],right_index=True,left_index=True)
auction = DataHandling.calItemsProfit(auction)
auction.drop_duplicates(inplace=True)

# %%
# check if the same, the second one should have 1 row less
print len(auction), len(temp_auction)
print auction[(auction['Item ID'] == 765) & (auction['Week Num'] == 37)]
print temp_auction[(temp_auction['Item ID'] == 765) & (temp_auction['Week Num'] == 37)]
# Out:
# 243162 243162
#         Item ID  Week Num  Avg Daily Posted
# 626039      765        37            290.29
# 629924      765        37            294.36
# 633834      765        37            296.14
# 637646      765        37            303.29
# 641476      765        37            298.14
# 645316      765        37            304.43
# 649219      765        37            320.00
#
# [7 rows x 3 columns]
#         Item ID  Week Num  AH MarketPrice
# 626039      765        37          0.2141
# 629924      765        37          0.1500
# 633834      765        37          0.1530
# 637646      765        37             NaN
# 641476      765        37          1.1000
# 645316      765        37          1.0200
# 649219      765        37          0.7499
#
# [7 rows x 3 columns]

# %% [markdown]
# Calculate weekly mean quantity of each item and weekly mean profit of a realm

# %%
auction = auction.ix[:, ['Week Num','Item ID','Avg Daily Posted','Profit']]
grouped_auction = auction.groupby(['Week Num','Item ID'], as_index=False)

# get "item weekly quantity"
item_q_weekly_mean = grouped_auction['Avg Daily Posted'].mean()

# get "totoal profit of a week"
item_profit_weekly_mean = grouped_auction['Profit'].mean()
realm_weekly_profit = item_profit_weekly_mean.groupby(['Week Num'])['Profit'].sum()

# %% [markdown]
# Now we have profit of any week(item_weekly_profit), merge it with auction dataframe

# %%
item_weekly_profit = DataFrame(realm_weekly_profit, columns=['Profit']).reset_index()
auction = item_q_weekly_mean.merge(item_weekly_profit)

# %% [markdown]
# Generate item id list

# %%
# need to extract every item.
temp_id_list = auction['Item ID']
temp_id_list = temp_id_list.drop_duplicates()
id_list = temp_id_list.tolist()

# %% [markdown]
# Calculate correlation coefficient of each data.

# %%
item_corr_df = DataFrame(columns=['Item ID','Corr'])
for item in id_list:
    temp_item = auction[auction['Item ID']==item]
    corr = np.corrcoef(x=temp_item['Avg Daily Posted'], y=temp_item['Profit'])
    new_corr = DataFrame([{'Item ID':item, 'Corr':corr[0][1]}])
    item_corr_df = item_corr_df.append(new_corr, ignore_index=True)
item_corr_df.to_csv('filename')
# Out:
#            Corr Item ID
# 0     0.1703423     118
# 1    -0.1794718     723
# 2      0.171834     765
# 3    -0.1288046     769
# 4    -0.2395361     774
# 5   -0.05157824     783
# 6    -0.1891406     785
# 7    0.06536628     789
# 8    -0.1178153     818
# 9     0.3098154     821
# 10    0.5887271     833
# 11    0.6654875     856
# 12  -0.05331981     863
# 13    0.1038125     864
# 14   -0.1471731     866
# 15  -0.03915693     929
# 16   -0.1518642    1015
# 17    0.7727077    1206
# 18   -0.6290471    1207
# 19   -0.2104366    1210
# 20   -0.1202874    1288
# 21   0.01323302    1391
# 22   0.07302622    1465
# 23    0.2893028    1468
# 24    0.3628567    1529
# 25    0.1183033    1608
# 26     0.219008    1639
# 27    0.1039007    1705
# 28  0.001678296    1710
# 29  -0.04033746    1722
# 30   -0.5707982    1926
# 31    0.4226809    1951
# 32   -0.4689475    1973
# 33    0.1538008    1979
# 34   -0.5152547    1994
# 35   -0.1336497    2073
# 36    0.3904547    2078
# 37    0.1978107    2087
# 38   -0.2963997    2236
# 39   -0.3794844    2244
# 40   0.09370654    2251
# 41    0.1505273    2291
# 42   -0.3834257    2300
# 43   -0.2861064    2304
# 44    0.1637592    2314
# 45   -0.4473403    2315
# 46  -0.05929062    2318
# 47   -0.1695378    2319
# 48    0.1254299    2408
# 49    0.4199007    2447
# 50  -0.04022596    2449
# 51 -0.004477121    2450
# 52   -0.1875501    2452
# 53     -0.20955    2453
# 54   0.03324114    2454
# 55    0.3998446    2455
# 56  -0.08216295    2459
# 57   -0.3060238    2553
# 58    0.0210342    2555
# 59   0.06242632    2589
#             ...     ...
#
# [7811 rows x 2 columns]

# %%
dfdf[(dfdf['Corr'] == 1) | (dfdf['Corr'] == -1)]
# Out:
#      Corr Item ID
# 164     1    4084
# 177    -1    4294
# 220     1    5011
# 250     1    6294
# 331     1    7441
# 363     1    8107
# 385     1    8216
# 437     1    9825
# 450     1    9906
# 620     1   14127
# 650     1   14566
# 681     1   15165
# 707     1   15378
# 718     1   15516
# 723     1   15569
# 738     1   15643
# 770     1   18294
# 786    -1   20817
# 828     1   22278
# 844    -1   22528
# 915     1   24199
# 918     1   24211
# 919     1   24243
# 941    -1   24766
# 963     1   24975
# 976     1   25034
# 981     1   25174
# 992     1   25384
# 1028    1   30748
# 1064   -1   34535
# 1096   -1   36050
# 1705    1   55520
# 1707    1   55562
# 2117   -1   82910
# 2160    1   85797
# 2234    1   90047
# 2252    1   90741
# 2258    1   90810
# 2275   -1   94097
# 2332    1  102351
# 2522   -1    7520
# 2560   -1    9853
# 2627   -1   13088
# 2632   -1   13816
# 2647   -1   14269
# 2656    1   14589
# 2676   -1   15146
# 2701   -1   15570
# 2783    1   25668
# 2785   -1   25675
# 2821   -1   33405
# 2823   -1   33424
# 2845   -1   36363
# 2886   -1   40133
# 2897    1   42434
# 2910    1   52098
# 2913   -1   52155
# 2928    1   55683
# 2985    1   79253
# 3012    1   82426
#       ...     ...
#
# [586 rows x 2 columns]

# %%
item_corr_df[(item_corr_df['Corr'] == 1) | (item_corr_df['Corr'] == -1)]
# Out:
#      Corr Item ID
# 177    -1    4294
# 251     1    6294
# 332     1    7441
# 364     1    8107
# 438     1    9825
# 451     1    9906
# 621     1   14127
# 640     1   14372
# 708     1   15378
# 719     1   15516
# 724     1   15569
# 787    -1   20817
# 829     1   22278
# 942    -1   24766
# 964     1   24975
# 977     1   25034
# 993     1   25384
# 1029    1   30748
# 1097   -1   36050
# 1184   -1   38797
# 1705   -1   55458
# 1710    1   55562
# 1741    1   59901
# 2163    1   85797
# 2237    1   90047
# 2255    1   90741
# 2261    1   90810
# 2265    1   92426
# 2272   -1   93496
# 2273    1   93574
# 2278   -1   94097
# 2335    1  102351
# 2383   -1      43
# 2520   -1    7460
# 2524   -1    7520
# 2537   -1    8189
# 2541   -1    8255
# 2545   -1    8291
# 2610    1   12030
# 2620   -1   12996
# 2629   -1   13088
# 2632   -1   13457
# 2634   -1   13816
# 2649   -1   14269
# 2658    1   14589
# 2678   -1   15146
# 2703   -1   15570
# 2785    1   25668
# 2820   -1   33377
# 2823   -1   33405
# 2847   -1   36363
# 2888   -1   40133
# 2912    1   52098
# 2930    1   55683
# 2936   -1   61980
# 2950    1   75129
# 2987    1   79253
# 3018    1   86844
# 3032   -1   87513
# 3080    1    3471
#       ...     ...
#
# [624 rows x 2 columns]

# %%
item_corr_df.sort(['Item ID'])
# Out:
#             Corr Item ID
# 6403           1      25
# 6404           1      37
# 2383          -1      43
# 6405           1      47
# 6406           1      48
# 3532 -0.04717534     117
# 0      0.1703423     118
# 4444           1     159
# 7184         NaN     200
# 4445   0.9972451     414
# 1     -0.1794718     723
# 2384  -0.5370008     724
# 3533  -0.1153375     727
# 5686   0.2810707     733
# 5507  -0.4569746     754
# 2       0.171834     765
# 4211         NaN     768
# 3     -0.1288046     769
# 4     -0.2395361     774
# 5    -0.05157824     783
# 6     -0.1891406     785
# 7698         NaN     787
# 7     0.06536628     789
# 3870   0.1235316     790
# 7185           1     796
# 3534         NaN     797
# 6577         NaN     804
# 2385   0.7511648     805
# 7186  -0.5844587     809
# 7568          -1     810
# 5128           1     812
# 8     -0.1178153     818
# 9      0.3098154     821
# 2386  -0.2972847     828
# 10     0.5887271     833
# 7187         NaN     839
# 7188         NaN     840
# 3871         NaN     844
# 6407           1     845
# 5908         NaN     846
# 2387         NaN     851
# 11     0.6654875     856
# 2388  -0.3120487     857
# 2389   0.3871962     858
# 12   -0.05331981     863
# 13     0.1038125     864
# 2390  -0.3115573     865
# 14    -0.1471731     866
# 5129         NaN     868
# 7569          -1     871
# 3872   0.4494237     890
# 3053         NaN     927
# 15   -0.03915693     929
# 6848  -0.1375066     934
# 7421          -1     935
# 6053         NaN     943
# 2391  -0.1401801     955
# 6179  -0.7861347     961
# 16    -0.1518642    1015
# 2392   0.1967171    1017
#              ...     ...
#
# [7811 rows x 2 columns]
